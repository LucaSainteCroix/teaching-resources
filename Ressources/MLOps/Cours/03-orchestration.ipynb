# %% [markdown]
# # Orchestration

# %% [markdown]
# **The goal**: going from notebooks or python scripts to a production-ready pipeline that can be scheduled and monitored.
#
# These are the traditional steps:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mage

# %% [markdown]
# Mage is an open-source, hybrid framework for transforming and integrating data.
#
# - **Extract** and synchronize data from 3rd party sources.
# - **Transform** data with real-time and batch pipelines using Python, SQL, and R.
# - **Load** data into your data warehouse or data lake using our pre-built connectors.
# - Run, monitor, and **orchestrate** thousands of pipelines without losing sleep.

# %% [markdown]
# ## Fundamental Concepts

# %% [markdown]
# https://docs.mage.ai/design/core-abstractions

# %% [markdown]
# ## Project Structure

# %% [markdown]
# https://docs.mage.ai/design/abstractions/project-structure
